# %%
from medtop.core import *
import medtop.internal as internal

# %%
data, doc_df = import_docs('test_data/corpus_file_list.txt')
tfidf, dictionary = create_tfidf('test_data/seed_topics_file_list.txt', doc_df)

# %%
doc_df = get_doc_topics(doc_df)
doc_df
# Out:
#    doc_id                       file  \
# 0       0  test_data/corpus/doc0.txt
# 1       1  test_data/corpus/doc1.txt
# 2       2  test_data/corpus/doc2.txt
# 3       3  test_data/corpus/doc3.txt
# 4       4  test_data/corpus/doc4.txt
# 5       5  test_data/corpus/doc5.txt
# 6       6  test_data/corpus/doc6.txt
# 7       7  test_data/corpus/doc7.txt
# 8       8  test_data/corpus/doc8.txt
# 9       9  test_data/corpus/doc9.txt
#
#                                                 text  \
# 0  I felt guilt because I was caught out lying ab...
# 1  I felt joy because my daughter scored in the h...
# 2  I felt guilt by not letting my sister help me ...
# 3  I felt sadness that a friend's pet rabbit had ...
# 4  I felt guilt when I bumped into a neighbour in...
# 5  I felt guilt when I encouraged my mother to re...
# 6  I felt joy when I found out that my 13 year ol...
# 7  I felt joy when I had bean soup. I felt joy wh...
# 8  I felt guilt when I inadvertently stole an air...
# ...

# %%
doc_df.topics.values
# Out:
# array([list(['felt', 'joy', 'guilt', 'see', 'sadness', 'time', 'shame', 'died', 'child', 'partner']),
#        list(['felt', 'sadness', 'joy', 'son', 'dog', 'died', 'daughter', 'mother', 'cancer', 'shame']),
#        list(['felt', 'guilt', 'joy', 'christmas', 'girlfriend', 'life', 'shame', 'night', 'loved', 'letting']),
#        list(['felt', 'sadness', 'guilt', 'joy', 'shame', 'ate', 'woman', 'broke', 'today', 'anniversary']),
#        list(['felt', 'guilt', 'shame', 'joy', 'sadness', 'parent', 'money', 'sick', 'cat', 'bill']),
#        list(['felt', 'guilt', 'forgot', 'joy', 'found', 'finally', 'got', 'driver', 'christmas', 'complete']),
#        list(['felt', 'joy', 'got', 'guilt', 'shame', 'found', 'affair', 'family', 'marital', 'married']),
#        list(['felt', 'sadness', 'heard', 'died', 'home', 'dog', 'joy', 'friend', 'well', 'family']),
#        list(['felt', 'guilt', 'lost', 'joy', 'lied', 'sadness', 'friend', 'necklace', 'old', 'managed']),
# ...
